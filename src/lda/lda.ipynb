]
for i in range(len(texts)):
   texts[i] = texts[i].split(" ")

# %%
texts[1][:5]
# Out:
# ['In', 'placerat', 'nisi', 'enim,', 'at']

# %%
# Create dictionaries of the words from the subtitles
id2word = corpora.Dictionary(texts)

# Construct the TDFs (Term Document Frequencies) for each text
corpus = [id2word.doc2bow(text) for text in texts]

# %%
# Creating/loading model from dataset
number_of_topics = 10
lda = LdaMulticore(corpus=corpus, id2word=id2word, num_topics=number_of_topics)

# %%
# Print all topics with top 10 keywords
pprint(lda.print_topics(number_of_topics))
# Out:
# [(0,
#   '0.007*"vitae" + 0.006*"commodo" + 0.006*"erat" + 0.006*"imperdiet" + '
#   '0.006*"sit" + 0.006*"at" + 0.006*"a" + 0.006*"in" + 0.005*"consectetur" + '
#   '0.005*"sapien"'),
#  (1,
#   '0.018*"id" + 0.014*"sit" + 0.013*"nec" + 0.013*"amet" + 0.011*"Quisque" + '
#   '0.010*"a" + 0.010*"aliquet" + 0.010*"vitae" + 0.010*"eu" + 0.009*"risus"'),
#  (2,
#   '0.019*"nec" + 0.014*"sit" + 0.013*"eu" + 0.013*"Quisque" + 0.012*"eleifend" '
#   '+ 0.012*"vitae" + 0.012*"urna" + 0.012*"Sed" + 0.012*"egestas" + '
#   '0.012*"faucibus"'),
#  (3,
#   '0.021*"vitae" + 0.018*"sit" + 0.013*"nec" + 0.012*"amet" + 0.011*"at" + '
#   '0.011*"erat" + 0.010*"Morbi" + 0.010*"commodo" + 0.010*"Ut" + '
#   '0.009*"Etiam"'),
#  (4,
#   '0.016*"Cras" + 0.014*"ac" + 0.013*"ornare" + 0.012*"auctor" + 0.012*"Sed" + '
#   '0.012*"a" + 0.012*"Quisque" + 0.012*"Mauris" + 0.012*"mi" + 0.011*"mattis"'),
#  (5,
#   '0.017*"sit" + 0.017*"vitae" + 0.017*"a" + 0.016*"id" + 0.016*"erat" + '
# ...

# %%
pyLDAvis.enable_notebook()

# %%
topic_visualization = gensimvis.prepare(lda, corpus, id2word)
# Out:
# /Users/magnusreierrushfeldt/src/personal/Master-Thesis-Project/.venv/lib/python3.9/site-packages/pyLDAvis/_prepare.py:243: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(

# %%
topic_visualization
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 5      0.039437 -0.057652       1        1  38.646187
# 8      0.039736  0.063395       2        1  37.482630
# 7     -0.107703  0.022124       3        1  21.444808
# 2      0.026783  0.030907       4        1   1.787478
# 9      0.034125 -0.026441       5        1   0.106488
# 3     -0.032567 -0.028285       6        1   0.106485
# 4      0.025690  0.008123       7        1   0.106485
# 6     -0.039013 -0.019683       8        1   0.106484
# 1      0.022904  0.011910       9        1   0.106483
# 0     -0.009394 -0.004398      10        1   0.106472, topic_info=        Term      Freq     Total Category  logprob  loglift
# 96       sit  7.000000  7.000000  Default  30.0000  30.0000
# 110    vitae  6.000000  6.000000  Default  29.0000  29.0000
# 55        id  6.000000  6.000000  Default  28.0000  28.0000
# 10         a  5.000000  5.000000  Default  27.0000  27.0000
# ...
